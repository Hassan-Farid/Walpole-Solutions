# %% [markdown]
# # Chapter 5 Section 1
#
# ## Examples
#
# ### Example 5.1:
# For the given case, the component will either survive or not with the condition that if one survives it does not change the fact that the second will survive or not. Hence, this is a baernoulli trial. We have for the given trial:
#
# n = 4 ; x = 2 ; p = 3/4 ; q = 1 - p = 1- 3/4 = 1/4
#
# Now, using the formula for a binomial distribution, we have:
#
# $b(x: n, p)$ = b(2: 4, 3/4) = $^4C_2$ $*$ (3/4)$^2$ $*$ (1/4)$^{4-2}$ = 6 $*$ 9/16 $*$ 1/16 = 27/128
#
# ### Example 5.2:
# For the given case, the patient will either survive or not with the condition that if one survives it does not change the fact that the second will survive or not. Hence, this is a bernoulli trial. Now, we have for the given cases:
#
# n = 15; p = 0.4 ; q = 1 - p = 1 - 0.4 = 0.6
#
# __(a)__ We have for at least 10 to survive:
#
# $P(X > 10)$ = 1 - $P(X < 10)$ = 1 - $\Sigma_{x=0}^{9} b(x: 15,0.4)$ ---(i)
#
# Now, for:
#
# $\Sigma_{x=0}^{9} b(x: 15.0.4)$ = $^{15}C_{0}$ $*$ (0.4)$^{0}$ $*$ (0.6)$^{15-0}$ + $^{15}C_{1}$ $*$ (0.4)$^{1}$ $*$ (0.6)$^{15-1}$ + $^{15}C_{2}$ $*$ (0.4)$^{2}$ $*$ (0.6)$^{15-2}$ + $^{15}C_{3}$ $*$ (0.4)$^{3}$ $*$ (0.6)$^{15-3}$ + $^{15}C_{4}$ $*$ (0.4)$^{4}$ $*$ (0.6)$^{15-4}$ + $^{15}C_{5}$ $*$ (0.4)$^{5}$ $*$ (0.6)$^{15-5}$ + $^{15}C_{6}$ $*$ (0.4)$^{6}$ $*$ (0.6)$^{15-6}$ + $^{15}C_{7}$ $*$ (0.4)$^{7}$ $*$ (0.6)$^{15-7}$ + $^{15}C_{8}$ $*$ (0.4)$^{8}$ $*$ (0.6)$^{15-8}$ + $^{15}C_{9}$ $*$ (0.4)$^{9}$ $*$ (0.6)$^{15-9}$ = 0.0004701 + 0.004701 + 0.0219 + 0.06338 + 0.12677 + 0.18594 + 0.2066 + 0.1771 + 0.1180 + 0.0612 = 0.9661
#
# (i) => $P(X > 10)$ = 1 - 0.9661 = 0.0339
#
# __(b)__ We have from 3 to 8 survive:
#
# $P(3 < X < 8)$ = $P(X < 8)$ - $P(X < 3)$ = $\Sigma_{x=0}^{7} b(x: 15,0.4)$ - $\Sigma_{x=0}^{2} b(x: 15,0.4)$ = 0.9050 - 0.0271 = 0.8779
#
# (Note: $\Sigma$ values are calculated using the method mentioned in part __(a)__ )
#
# __(c)__ We have for exactly 5 to survive:
#
# $P(X = 5)$ = $b(5: 15,0.4)$ = $^{15}C_5$ $*$ (0.4)$^5$ (0.6)$^{10}$ = 0.1859
#
# ### Example 5.3:
# The device to be selected is either defective or non-defective i.e. it is a trial of either success or failure, such that if one device is defected it does not have an impact on whether the other is defective or not. Thus, this is a bernoulli trial, for which we have:
#
# p = 3% = 0.03 ; q = 1 - p = 1 - 0.03 = 0.97
#
# __(a)__ We have, for the given case:
#
# n = 20 ; x >= 1
#
# $P(X >= 1)$ = 1 - P(X = 0) = 1 - $b(0: 20,0.03)$ = 1 - $^{20}C_{0}$ $*$ (0.03)$^{0}$ $*$ (0.97)$^{20}$ = 1 - 1 $*$ 1 $*$ 0.5438 = 1 - 0.5438 = 0.4562
#
# __(b)__ For this case, we suppose X is the random variable representing the number of defective devices in a shipment of 20 devices and Y be the random variable representing the number of shipments that will contain a defective device, then:
#
# Using part(a), we have for atleast one defective device in a shipment:
#
# $P(X >= 1)$ = 0.4562
#
# Now, we have for the number of shipments with defective devices:
#
# n = 10; y = 3; p = 0.4562; q = 1 - p = 1 - 0.4562 = 0.5438
#
# $P(Y = 3)$ = $b(y: n,p)$ = $b(3: 10,0.4562)$ = $^{10}C_3$ $*$ (0.4562)$^3$ $*$ (0.5438)$^7$ = 120 $*$ 0.0949 $*$ 0.0141 = 0.1608
#
# ### Example 5.4:
# The wells are either filled with impure water or pure water, hence, the trial is either a success or a failure with the case that a certain containing impure water doesn't have an impact on the other wells as to whether they will be impure or not. No, for the given case, we have:
#
# n = 10; p = 30% = 0.3 ; q = 1 - p = 1 - 0.3 = 0.7
#
# __(a)__ For the given case, we have:
#
# $P(X = 3)$ = $b(x: n,p)$ = $^{10}C_3$ $*$ (0.3)$^3$ $*$ (0.7)$^7$ = 120 $*$ 0.027 $*$ 0.082 = 0.2656
#
# __(b)__ For the given case, we have:
#
# $P(X > 3)$ = 1 - P($X <= 3$) = 1 - $\Sigma_{x=0}^{3} b(x: n,p)$ = 1 - ($b(0: 10,0.3)$ + $b(1: 10,0.3)$ + $b(2: 10,0.3)$ + $b(3: 10,0.3)$) = 1 - ($^{10}C_{0}$ $*$ (0.3)$^0$ $*$ (0.7)$^{10-0}$ + $^{10}C_{1}$ $*$ (0.3)$^1$ $*$ (0.7)$^{10-1}$ + $^{10}C_{2}$ $*$ (0.3)$^2$ $*$ (0.7)$^{10-2}$ + $^{10}C_{3}$ $*$ (0.3)$^3$ $*$ (0.7)$^{10-3}$) = 1 - (0.0282 + 0.1211 + 0.2335 + 0.2668) = 1 - 0.6496 = 0.3504
#
# ### Example 5.5:
# For the example in 5.2, we have:
#
# n = 15; p = 0.4; q = 0.6
#
# Mean = $\mu$ = np = (15)(0.4) = 6 ; Variance = $\sigma^2$ = npq = (15)(0.4)(0.6) = 3.6
#
# Now, to apply Chebyshev's theorem, we need std(Standard Deviation) i.e.
#
# $\sigma$ = $\sqrt{\sigma^2}$ = $\sqrt{3.6}$ = 1.897
#
# Thus, we have by Chebyshev's theorem, the interval: $\mu$ +- 2$\sigma$ = 6 - 2(1.897) to 6 + 2(1.897) = 2.206 to 9.794
#
# ### Example 5.6:
# Considering the case in Example 5.4, we have:
#
# n = 10; p = 0.3; q = 0.7
#
# $P(X \geq 6)$ = 1 - $P(X < 5)$ = 1 - $\Sigma_{x = 0}^{5} b(x: 10,0.3)$ = 1 - ($b(0: 10,0.3)$ + $b(1: 10,0.3)$ + $b(2: 10,0.3)$ + $b(3: 10,0.3)$ + $b(4: 10,0.3)$ + $b(5: 10,0.3)$) = 1 - ($^{10}C_{0}$ $*$ (0.3)$^0$ $*$ (0.7)$^{10-0}$ + $^{10}C_{1}$ $*$ (0.3)$^1$ $*$ (0.7)$^{10-1}$ + $^{10}C_{2}$ $*$ (0.3)$^2$ $*$ (0.7)$^{10-2}$ + $^{10}C_{3}$ $*$ (0.3)$^3$ $*$ (0.7)$^{10-3}$ + $^{10}C_{4}$ $*$ (0.3)$^4$ $*$ (0.7)$^{10-4}$ + $^{10}C_{5}$ $*$ (0.3)$^5$ $*$ (0.7)$^{10-5}$) = 1 - (0.0282 + 0.1211 + 0.2335 + 0.2668 + 0.2001 + 0.1029) = 1 - 0.9526 = 0.0474
#
# __Conclusion:__
# As a result, it is very unlikely (4.7% chance) that 6 or more wells would be found impure if only 30% of all are impure. This casts considerable doubt on the conjecture and suggests that the impurity problem is much more severe.
#
# ### Example 5.7:
# Assume that R1, R2 and R3 be the events that the airplanes access the runways 1,2 and 3 respectively, then we have:
#
# p1 = P(R1) = 2/9 ; p2 = P(R2) = 1/6 ; p3 = P(R3) = 11/18 ; $x_1$ = 2 ; $x_2$ = 1 ; $x_3$ = 3 ; n = 6
#
# Now, using formula for multinomial distribution:
#
# $f(x_1, x_2, x_3; p1, p2, p3, n)$ = $f(2,1,3; 2/9, 1/6, 11/18, 6)$ = (6!/(2! $*$ 1! $*$ 3!)) $*$ (2/9)$^2$ $*$ (1/6)$^1$ $*$ (11/18)$^3$ = 60 $*$ 4/81 $*$ 1/6 $*$ 1331/5832 = 0.1127
#
# ## Exercises:
#
# ### Exercise 5.1:
# For the given function, we have:  $p_X(x)$ = 1/k
#
# Mean = $\mu$ = $E[X]$ = $\Sigma_{x} xp_X(x)$ = $\Sigma_{i=1}^{k} x_i/k$
#
# Variance = $\sigma^2$ = $\Sigma_{x} (x - \mu)^2 p_X(x)$ = $\Sigma_{i=1}^{k} (x_i - \mu)^2/k$
#
# ### Exercise 5.2:
# Let D be the event that the person finds a difference and N be the event that he does not. Let X be the random variable representing the number of people who heard a difference between the speakers. Since, the trial has only two possible outcomes i.e. either the person will hear a difference or not, such that the claim of one person does not affect the claim of the other, thus, this is a bernoulli trial, for which we have:
#
# n = 12; x = 3; p = 0.5; q = 1 - p = 1 - 0.5 = 0.5
#
# (We take probability as 0.5 because both the events are equally likely and the people are guessing randomly)
#
# Now, using formula for binomial distribution:
#
# $P(X = 3)$ = $b(x: n,p)$ = $b(3: 12,0.5)$ = $^{12}C_3$ $*$ (0.5)$^3$ $*$ (0.5)$^{12-3}$ = 0.0537
#
# ### Exercise 5.3:
# For the given case, let X be the random variable representing the tag number that has been selected. Now, since at most one tag can be selected at a time from a total of 10, the probability for selecting a certain tag at random would be given by the probability distribution formula:
#
# $p_X(x)$ = 1/10 ; x = 1,2,3,....10 and $p_X(x)$ = 0 ; otherwise
#
# Now, for probability that a number less than 4 is drawn, we have:
#
# n = 10; p = 1/10 = 0.1; q = 1 - p = 1 - 0.1 = 0.9
#
# $P(X < 4)$ = $\Sigma_{x=1}^{3} b(x: n,p)$ = $b(1: 10,0.1)$ + $b(2: 10,0.1)$ + $b(3: 10,0.1)$ = $^{10}C_1$ $*$ (0.1)$^1$ $*$ (0.9)$^{10-1}$ + $^{10}C_2$ $*$ (0.1)$^2$ $*$ (0.9)$^{10-2}$ + $^{10}C_3$ $*$ (0.1)$^3$ $*$ (0.9)$^{10-3}$ = 0.3874 + 0.1937 + 0.0574 = 0.6385
#
# ### Exercise 5.4:
# Let X be the random variable representing the number of cases caused due to need for money to buy drugs, then we have:
#
# n = 5; p = 75% = 0.75; q = 1 - p = 1 - 0.75 = 0.25
#
# This is a bernoulli trial, as the reason for theft may either be caused by the need for money to buy drugs or not, such that the reason for first theft will not affect the reason for the second
#
# __(a)__ For the given case, we have:
#
# $P(X = 2)$ = $b(2: 5,0.75)$ = $^5C_2$ $*$ (0.75)$^2$ $*$ (0.25)$^{5-2}$ = 0.0878
#
# __(b)__ For the given case, we have: (At most 3 means not more than 3)
#
# $P(X \leq 3)$ = $\Sigma_{x=0}^{3} b(x: n,p)$ = $b(0: 5,0.75)$ + $b(1: 5,0.75)$ + $b(2: 5,0.75)$ + $b(3: 5,0.75)$ = $^5C_0$ $*$ (0.75)$^0$ $*$ (0.25)$^{5-0}$ + $^5C_1$ $*$ (0.75)$^1$ $*$ (0.25)$^{5-1}$ + $^5C_2$ $*$ (0.75)$^2$ $*$ (0.25)$^{5-2}$ + $^5C_3$ $*$ (0.75)$^3$ $*$ (0.25)$^{5-3}$ = 0.00098 + 0.01464 + 0.08789 + 0.26367 = 0.36718
#
# ### Exercise 5.5:
# Let X be the random variable representing the number of pipework failures caused by operator error, then we have:
#
# p = 30% = 0.3 ; q = 1 - p = 1 - 0.3 = 0.7
#
# __(a)__ For the given case, we have:
#
# n = 20; x $\geq$ 10
#
# $P(X \geq 10)$ = 1 - $P(X < 9)$ = 1 - $\Sigma_{x=0}^{9} b(x: n,p)$ = 1 - ($b(0: 20,0.3)$ + $b(1: 20,0.3)$ + $b(2: 20,0.3)$ + $b(3: 20,0.3)$ + $b(4: 20,0.3)$ + $b(5: 20,0.3)$ + $b(6: 20,0.3)$ + $b(7: 20,0.3)$ + $b(8: 20,0.3)$ + $b(9: 20,0.3)$) = 1 - (0.00079 + 0.00684 + 0.02784 + 0.07160 + 0.13042 + 0.17886 + 0.19164 + 0.16426 + 0.11439 + 0.06537) = 1 - 0.95201 = 0.04799
#
# __(b)__ For the given case, we have:
#
# $P(X \leq 4)$ = $\Sigma_{x=0}^{4} b(x: n,p)$ = $b(0: 20,0.3)$ + $b(1: 20,0.3)$ + $b(2: 20,0.3)$ + $b(3: 20,0.3)$ + $b(4: 20,0.3)$ = 0.00079 + 0.00684 + 0.02784 + 0.07160 + 0.13042 = 0.28749
#
# __(c)__ For the given case, we have:
#
# $P(X = 5)$ = $b(5: 20,0.3)$ = $^{20}C_5$ $*$ (0.3)$^5$ $*$ (0.7)$^{20-5}$ = 0.17886 (The probability is close to that given i.e. 0.3, hence, the figure of 30% applies to the plant)
#
# ### Exercise 5.6:
# Let X be the random variable representing the companies that give a vacation of 4 weeks to employees after 15 years, we have:
#
# n = 6; p = 0.5; q = 1 - p = 1 - 0.5 = 0.5
#
# (We take probability as 0.5 as the chance of getting vacations or not is equally likely)
#
# __(a)__ For the given case, we have:
#
# $P(2 \leq X \leq 5)$ = $P(X \leq 5)$ - $P(X \leq 1)$ = (1 - $P(X = 6)$) - $P(X \leq 1)$ = (1 - $b(6: 6,0.5)$) - ($\Sigma_{x = 0}^{1} b(x: n,p)$) = (1 - 0.0156) - ($b(0: 6,0.5)$ + $b(1: 6,0.5)$) = 0.9844 - (0.0156 + 0.09375) = 0.9844 - 0.1093 = 0.8751
#
# __(b)__ For the given case, we have:
#
# $P(X < 3)$ = $\Sigma_{x=0}^{2} b(x: n,p)$ = $b(0: 6,0.5)$ + $b(1: 6,0.5)$ + $b(2: 6,0.5)$ = 0.0156 + 0.09375 + 0.2343 = 0.3436
#
# ### Exercise 5.7:
# Let X be the random variable representing the number of patients with lung cancer that are chain smokers, then we have:
#
# p = 70% = 0.7; q = 1 - p = 1 - 0.7 = 0.3
#
# __(a)__ For the given case, we have:
#
# n = 10; x < n/2 = 5
#
# $P(X < 5)$ = $\Sigma_{x=0}^{4} b(x: n,p)$ = $b(0: 10,0.7)$ + $b(1: 10,0.7)$ + $b(2: 10,0.7)$ + $b(3: 10,0.7)$ + $b(4: 10,0.7)$ = 0.000006 + 0.000138 + 0.001446 + 0.009002 + 0.036757 = 0.04735
#
# __(b)__ For the given case, we have:
#
# n = 20; x < n/2 = 10
#
# $P(X < 10)$ = $\Sigma_{x=0}^{9} b(x: n,p)$ = $b(0: 20,0.7)$ + $b(1: 20,0.7)$ + $b(2: 20,0.7)$ + $b(3: 20,0.7)$ + $b(4: 20,0.7)$ + $b(5: 20,0.7)$ + $b(6: 20,0.7)$ + $b(7: 20,0.7)$ + $b(8: 20,0.7)$ + $b(9: 20,0.7)$ = 0.0171
#
# (Note: Values will be computed in the same procedure)
#
# ### Exercise 5.8:
# Let X be the random variable representing the users that took Valium for psychological problems, then we have:
#
# n = 8; p = 60% = 0.6; q = 1 - p = 1 - 0.6 = 0.4
#
# __(a)__ For the given case, we have:
#
# $P(X = 3)$ = $b(3: 8,0.6)$ = $^8C_3$ $*$ (0.6)$^3$ $*$ (0.4)$^{8-3}$ = 0.1238
#
# __(b)__ For the given case, we have if there are atleast 5 people taking Valium for non-psychological problems then at most 3 people will be taking it for psycological problems i.e.
#
# $P(X \leq 3)$ = $\Sigma_{x=0}^{3} b(x: n,p)$ = $b(0: 8,0.6)$ + $b(1: 8,0.6)$ + $b(2: 8,0.6)$ + $b(3: 8,0.6)$ = 0.00065 + 0.00786 + 0.04128 + 0.12386 = 0.17365
#
# ### Exercise 5.9:
# Let X be the random variable representing the trucks that fail without a blowout, then we have:
#
# n = 15; p = 25% = 0.25; q = 1 - p = 1 - 0.25 = 0.75
#
# __(a)__ For the given case, we have:
#
# $P(3 \leq X \leq 6)$ = $\Sigma_{x=3}^{6} b(x: n,p)$ = $b(3: 15,0.25)$ + $b(4: 15,0.25)$ + $b(5: 15,0.25)$ + $b(6: 15,0.25)$ = 0.2252 + 0.2252 + 0.1651 + 0.0917 = 0.7072
#
# __(b)__ For the given case, we have:
#
# $P(X < 4)$ = $\Sigma_{x=0}^{3} b(x: n,p)$ = $b(0: 15,0.25)$ + $b(1: 15,0.25)$ + $b(2: 15,0.25)$ + $b(3: 15,0.25)$ = 0.0134 + 0.0668 + 0.1559 + 0.2252 = 0.4613
#
# __(c)__ For the given case, we have:
#
# $P(X > 5)$ = 1 - $P(X \leq 5)$ = 1 - ($\Sigma_{x=0}^{5} b(x: n,p)$) = 1 - ($b(0: 15,0.25)$ + $b(1: 15,0.25)$ + $b(2: 15,0.25)$ + $b(3: 15,0.25)$ + $b(4: 15,0.25)$ $b(5: 15,0.25)$) = 1 - (0.0134 + 0.0668 + 0.1559 + 0.2252 + 0.2252 + 0.1651) = 1 - 0.8516 = 0.1484
#
# ### Exercise 5.10:
# Let X be the random variable representing the seniors who disapprove of daily pot smoking, then we have:
#
# n = 12; p = 70% = 0.7; q = 1 - p = 1 - 0.7 = 0.3
#
# __(a)__ For the given case, we have:
#
# $P(7 \leq X \leq 9)$ = $\Sigma_{x=7}^{9} b(x: n,p)$ = $b(7: 12,0.7)$ + $b(8: 12,0.7)$ + $b(9: 12,0.7)$ = 0.1585 + 0.2311 + 0.2397 = 0.6293
#
# __(b)__ For the given case, we have:
#
# $P(X \leq 5)$ = $\Sigma_{x=0}^{5} b(x: n,p)$ = $b(0: 12,0.7)$ + $b(1: 12,0.7)$ + $b(2: 12,0.7)$ + $b(3: 12,0.7)$ + $b(4: 12,0.7)$ + $b(5: 12,0.7)$ = 0.0000005 + 0.0000149 + 0.0001909 + 0.0014852 + 0.0077977 + 0.0291114 = 0.0386
#
# __(c)__ For the given case, we have:
#
# $P(X \geq 8)$ = 1 - $P(X \leq 7)$ = 1 - ($\Sigma_{x=0}^{7} b(x: n,p)$) = 1 - ($b(0: 12,0.7)$ + $b(1: 12,0.7)$ + $b(2: 12,0.7)$ + $b(3: 12,0.7)$ + $b(4: 12,0.7)$ + $b(5: 12,0.7)$ + $b(6: 12,0.7)$ + $b(7: 12,0.7)$) = 1 - (0.0000005 + 0.0000149 + 0.0001909 + 0.0014852 + 0.0077977 + 0.0291114 + 0.0792478 + 0.1584958) = 1 - 0.2763 = 0.7237
#
# ### Exercise 5.11:
# Let X be the random variable representing the number of patients that survive then we have:
#
# n = 7; x = 5; p = 0.9; q = 1 - p = 1 - 0.9 = 0.1
#
# Now,
#
# $P(X = 5)$ = $b(5: 7,0.9)$ = $^7C_5$ $*$ (0.9)$^5$ $*$ (0.1)$^{7-5}$ = 21 $*$ 0.5905 $*$ 0.01 = 0.124
#
# ### Exercise 5.12:
# Let X be the random variable representing the number of vehicles out of state, then we have: (note that probability of X will be 25% as the given probability is for vehicles in the state)
#
# n = 9; p = 25% = 0.25; q = 1 - p = 1 - 0.25 = 0.75
#
# For the given case i.e. less than 4 vehicles, we have:
#
# $P(X < 4)$ = $\Sigma_{x=0}^{3} b(x: n,p)$ = $b(0: 9,0.25)$ + $b(1: 9,0.25)$ + $b(2: 9,0.25)$ + $b(3: 9,0.25)$ = 0.075 + 0.225 + 0.300 + 0.234 = 0.834
#
# ### Exercise 5.13:
# Let X be the random variable representing the people that hold the given opinion then we have:
#
# n = 5 ; x = 3; p = 70% = 0.7; q = 1 - p = 1  0.7 = 0.3
#
# Now, we have:
#
# $P(X = 3)$ = $b(3: 5,0.7)$ = $^5C_3$ $*$ (0.7)$^3$ $*$ (0.3)$^{5-3}$ = 10 $*$ 0.343 $*$ 0.09 = 0.3087
#
# ### Exercise 5.14:
# Let X be the random variable representing the wins for the Chicago Bulls in the game, then we have: (Best of 7 series is a series in which 7 games are played 3-3 and then final game is decided using the fourth game)
#
# n = 7; p = 90% = 0.9; q = 1 - p = 1 - 0.9 = 0.1
#
# __(a)__ For the Bulls to sweep (4-0) we have:
#
# $P(X = 4)$ = $b(4: 7,0.9)$ = $^7C_4$ $*$ (0.9)$^4$ $*$ (0.1)$^{7-4}$ = 35 $*$ 0.6561 $*$ 0.001 = 0.0229
#
# __(b)__ For the Bulls to win the best of 7 series (they can either sweep (4-0), (5-0), (6-0), (7-0)), hence we have:
#
# $P(4 \leq X \leq 7)$ = $\Sigma_{x=4}^{7} b(x: n,p)$ = $b(4: 7,0.9)$ + $b(5: 7,0.9)$ + $b(6: 7,0.9)$ + $b(7: 7,0.9)$ = 0.0229 + 0.1240 + 0.3720 + 0.4783 = 0.9972
#
# __(c)__ For the given case, we assume the fact that the Bulls always win by a probability of 0.9 in the games.
#
# ### Exercise 5.15:
# Let X be the random variable representing the number of mice that contract the disease, then we have: (probability for the variable will be 40% because we are given for mice to be protected whereas we are calculating for them to contract the disease)
#
# n = 5; p = 40% = 0.4; q = 60% = 0.6
#
# __(a)__ For the given case, we have:
#
# $P(X = 0)$ = $b(0: 5,0.4)$ = 0.6$^5$ = 0.0777
#
# __(b)__ For the given case, we have:
#
# $P(X < 2)$ = $\Sigma_{x=0}^{1} b(x: n,p)$ = $b(0: 5,0.4)$ + $b(1: 5,0.4)$ = 0.0777 + 0.2592 = 0.3369
#
# __(c)__ For the given case, we have:
#
# $P(X > 3)$ = $P(X = 4)$ + $P(X = 5)$ = $b(4: 5,0.4)$ + $b(5: 5,0.4)$ = 0.0768 + 0.0102 = 0.087
#
# ### Exercise 5.16:
# Let X be the random variable representing the number of engines for which the aeroplane lands a safe flight, then we have: (This will be 0.6 since we are given the probability of failing)
#
# p = 0.6; q = 0.4
#
# __For the 2-Engine Plane:__
# For the 2-engine plane, atleast 1 of its engine should be running i.e. we have: n = 2
#
# $P(X \geq 1)$ = 1 - $P(X = 0)$ = 1 - $b(0: 2,0.6)$ = 1 - $^2C_0$ $*$ (0.6)$^0$ $*$ (0.4)$^2$ = 1 - 0.16 = 0.84
#
# __For the 4-Engine Plane:__
# For the 4-engine plane, atleast 2 of its engines should be running i.e. n = 4
#
# $P(X \geq 2)$ = 1 - $P(X \leq 1)$ = 1 - ($P(X = 0)$ + $P(X = 1)$) = 1 - ($b(0: 4,0.6)$ + $b(1: 4,0.6)$) = 1 - (0.0256 + 0.1536) = 1 - 0.1792 = 0.8208
#
# Hence, the 2-engine plane has more probability of survival
#
# ### Exercise 5.17:
# We have from the case in Example 5.13:
#
# n = 5; p = 0.7; q = 0.3
#
# Mean = $\mu$ = np = (5)(0.7) = 3.5; Variance = $\sigma^2$ = npq = (5)(0.7)(0.3) = 1.05
#
# ### Exercise 5.18:
# We have from the case in Example 5.9:
#
# n = 15; p = 0.25; q = 0.75
#
# __(a)__ For the given case , we have:
#
# Expected Value = Mean = $\mu$ = np = (15)(0.25) = 3.75
#
# __(b)__ For the given case, we have:
#
# Variance = $\sigma^2$ = npq = (15)(0.25)(0.75) = 2.8125
#
# ### Exercise 5.19:
# For the given conditon, we have:
#
# $X_1$: the number of times student encounters a green light
#
# $X_2$: the number of times student encounters a yellow light
#
# $X_3$: the number of times student encounters a red light
#
# Now, assuming that the probabilities for the given random variables are $p_1$, $p_2$ and $p_3$ respectively, we have:
#
# $p_1$ = 35/100 = 0.35; $p_2$ = 5/100 = 0.05; $p_3$ = 60/100 = 0.6
#
# We have for the multi-nomial distribution for total time n:
#
# $f = (n! / (x_1! * x_2! * x_3!)) * (0.35)^{x_1} * (0.05)^{x_2} * (0.6)^{x_3}$
#
# ### Excercise 5.20:
# Let C be the random variable representing the cocaine users, M be the random variable representing the marijuana users and X be the random variable representing users for other drugs, then we have:
#
# $p_M$ = 54.4% = 54.4/100 = 0.544; $p_C$ = 22.5% = 22.5/100 = 0.225; $p_X$ = 1 - $p_C$ - $p_M$ = 1 - 0.769 = 0.231
#
# __(a)__ For the given case, we have:
#
# n = 10; c = 2; m = 5; x = 3
#
# $P(C = 2, M = 5, X = 3)$ = $f(c,m,x: p_C, p_M, p_X, n)$ = $f(2,5,3: 0.544, 0.225, 0.231, 10)$ = 10!/(2! $*$ 5! $*$ 3!) $*$ (0.225)$^2$ $*$ (0.544)$^5$ $*$ (0.231)$^3$ = 2520 $*$ 0.0506 $*$ 0.0476 $*$ 0.0123 = 0.0746
#
# __(b)__ For the given case, we have:
#
# n = 10; c = 0; m = 10; x = 0;
#
# $P(C = 0, M = 10, X = 0)$ = $f(0,10,0: 0.225,0.544,0.231, 10)$ = 10!/10! $*$ (0.225)$^0$ $*$ (0.544)$^10$ $*$ (0.231)$^0$ = 0.0023
#
# __(c)__ For the given case, we can say:
#
# n = 10; c = 0; y = m + x = 10 => $p_Y$ = 0.544 + 0.231 = 0.775
#
# $P(C = 0, Y = 10)$ = $f(0,10: 0.225,0.775, 10)$ = 10!/(0! $*$ 10!) $*$ (0.225)$^0$ $*$ (0.775)$^10$ = 0.0782
#
# ### Exercise 5.21:
# Let:
#
# B: Random variable representing the number of Bull's eye hit
#
# T: Random variable representing the number of Triples hit
#
# D: Random varaible representing the number of Doubles hit
#
# S: Random variable representing the number of Single hit
#
# M: Random variable representing the number of Complete Miss
#
# For given situation, we have:
#
# $p_B$ = 0.01; $p_T$ = 0.05; $p_D$ = 0.10; $p_M$ = 0.02; $p_S$ = 1 - ($p_B$ + $p_T$ + $p_D$ + $p_M$) = 1 - 0.18 = 0.82
#
# Now, we have:
#
# $P(B = 0, T = 0, D = 2, S = 4, M = 1)$ = $f(b,t,d,s,m: 0.01,0.05,0.10,0.82,0.02,7)$ = 7!/(2! $*$ 4! $*$ 1!) $*$ (0.01)$^0$ $*$ (0.05)$^0$ $*$ (0.10)$^2$ $*$ (0.82)$^4$ $*$ (0.02)$^1$ = 0.0095
#
# ### Exercise 5.22:
# Let:
#
# B: Random variable representing the number of black guinea pigs
#
# W: B: Random variable representing the number of white guinea pigs
#
# R: B: Random variable representing the number of red guinea pigs
#
# For given situation, we have:
#
# R:B:W = 8:4:4 = 2:1:1 => $p_R$ = 1/2 = 0.5 ; $P_B$ = 1/4 = 0.25 ; $P_W$ = 1/4 = 0.25
#
# Now, we have:
#
# $P(R = 5, B = 2, W = 1)$ = $f(r,b,w: 0.5,0.25,0.25,8)$ = 8!/(5! $*$ 2! $*$ 1!) $*$ (0.5)$^5$ $*$ (0.25)$^2$ $*$ (0.25)$^1$ = 0.082
#
# ### Exercise 5.23:
# Let:
#
# A: Random variable representing the arrival of delegate by air
#
# B: Random variable representing the arrival of delegate by bus
#
# M: Random variable representing the arrival of delegate by automobile
#
# T: Random variable representing the arrival of delegate by train
#
# For given condition, we have:
#
# $p_A$ = 0.4; $p_B$ = 0.2; $p_M$ = 0.3; $p_T$ = 0.1
#
# We have:
#
# $P(A = 3, B = 3; M = 1; T = 2)$ = $f(a,b,m,t: 0.4,0.2,0.3,0.1,9)$ = 9!/(3! $*$ 3! $*$ 1! $*$ 2!) $*$ (0.4)$^3$ $*$ (0.2)$^3$ $*$ (0.3)$^1$ $*$ (0.1)$^2$ = 0.00774
#
# ### Exercise 5.24:
# Let X be the number of workers wearing safety helmets while eating lunch, then we have:
#
# x = 4; n = 6; p = 40% = 0.4; q = 1 - p = 1 - 0.4 = 0.6
#
# Now, we have:
#
# $P(X = 4)$ = $b(4: 6,0.4)$ = $^6C_4$ $*$ (0.4)$^4$ $*$ (0.6)$^{6-4}$ = 0.1382
#
# ### Exercise 5.25:
# Let X be the number of chips that fail, then we have:
#
# x = 3; n = 20; p = 0.1; q = 1 - p = 1 - 0.1 = 0.9
#
# Now, we have:
#
# $P(X = 3)$ = $b(3: 20,0.1)$ = $^{20}C_3$ $*$ (0.1)$^3$ $*$ (0.9)$^{20-3}$ = 0.1901
#
# ### Exercise 5.26:
# __(a)__ and __(b)__ parts have been combined as the procedure is almost the same both ways (Mostly you won't have a table like one given in Appendix A.1 so its better to perfomr using the general method of binomial distribution)
#
# Let X be the random variable representing the number of automobile accidents due to speed violation, then we have:
#
# x = 6; n = 8; p = 6/10 = 0.6; q = 1 - p = 1 - 0.6 = 0.4
#
# Now, we have:
#
# $P(X = 6)$ = $b(6: 8,0.6)$ = $^8C_6$ $*$ (0.6)$^6$ $*$ (0.4)$^{8-6}$ = 0.2090
#
# ### Exercise 5.27:
# Let X be the random variable representing the number of flourescent lights having a life of atleast 800 hours, then we have:
#
# n = 20; p = 0.9; q = 1 - p = 1 - 0.9 = 0.1
#
# __(a)__ For the given case, we have:
#
# $P(X = 18)$ = $b(18: 20,0.9)$ = $^{20}C_{18}$ $*$ (0.9)$^{18}$ $*$ (0.1)${20-18}$ = 0.2852
#
# __(b)__ For the given case, we have:
#
# $P(X \geq 15)$ = $\Sigma_{x=15}^{20} b(x: n,p)$ = $b(15: 20,0.9)$ + $b(16: 20,0.9)$ + $b(17: 20,0.9)$ + $b(18: 20,0.9)$ + $b(19: 20,0.9)$ + $b(20: 20,0.9)$ = 0.0319 + 0.0898 + 0.1901 + 0.2852 + 0.2701 + 0.1216 = 0.9887
#
# __(c)__ For the given case, we have: (since at least 2 will not have a useful life at least 800 hours, thus, atmost 18 will have useful life)
#
# $P(X \leq 18)$ = 1 - $P(X \geq 19)$ = 1 - ($P(X = 19)$ + $P(X = 20)$) = 1 - ($b(19: 20,0.9)$ + $b(20: 20,0.9)$) = 1 - (0.2701 + 0.1216) = 1 - 0.3917 = 0.6083
#
# ### Exercise 5.28:
# Suppose that the number of toasters to be repaired after 1 year is represented by the random variable X, then for given condition, we have:
#
# n = 20; p = 0.2; q = 1 - p =  1 - 0.2 = 0.8
#
# __(a)__ For given case, we have:
#
# $P(X \geq x)$ < 0.5 => 1 - $P(X < x)$ < 0.5 => 1 - $P(X \leq x-1)$ < 0.5
#
# Now, we applying fomrula for binomial distribution:
#
# => 1 - $b(x-1: n,p)$ < 0.5
#
# __For X = 1:__ 1 - $b(0: 20,0.2)$ = 1 - 0.0115 = 0.9884 $\nless$ 0.5
#
# __For X = 2:__ 1 - ($b(0: 20,0.2)$ + $b(1: 20,0.2)$) = 1 - (0.0115 + 0.0576) = 0.9309 $\nless$ 0.5
#
# __For X = 3:__ 1 - ($b(0: 20,0.2)$ + $b(1: 20,0.2)$ + $b(2: 20,0.2)$) = 1 - (0.0115 + 0.0576 + 0.1369) = 0.794 $\nless$ 0.5
#
# __For X = 4:__ 1 - ($b(0: 20,0.2)$ + $b(1: 20,0.2)$ + $b(2: 20,0.2)$ + $b(3: 20,0.2)$) = 1 - (0.0115 + 0.0576 + 0.1369 + 0.2053) = 0.5887 $\nless$ 0.5
#
# __For X = 5:__ 1 - ($b(0: 20,0.2)$ + $b(1: 20,0.2)$ + $b(2: 20,0.2)$ + $b(3: 20,0.2)$ + $b(4: 20,0.2)$) = 1 - (0.0115 + 0.0576 + 0.1369 + 0.2053 + 0.1745) = 0.4142 < 5
#
# Hence, the value of x will be 5

# %% [markdown]
# # Chapter 5 Section 2:
#
# ## Examples:
#
# ### Example 5.8:
# To check whether the plan suggested is acceptable or not, we apply hetrogeometric function for 2 defective parts i.e. for the sample containing 3 parts out of 10 we have:
#
# k = 2; N = 10 => N-k = 8; n = 3
#
# Now, the lot is accepted if no defective component is found from the sample, thus, we assume that 0 defective parts were selected from the 2 while 3 non-defective parts were selected from the sample, with a total of selecting 3 parts from 10 i.e. we have:
#
# $P(X = 0)$ = ($^kC_x * ^{N-k}C_{n-x}$)/($^{10}C_3$) = $^2C_0 * 8C_3$ / 120 = 56/120 = 0.4667 => 46.67%
#
# This indicates that a sample containing 2 defective parts and 8 non-defective parts would be accepted 46.67% of the time, which indicates that the system is faulty.
#
# ### Example 5.9:
# For 1 defective found in the sample for total of 3 defective in the sample, then we have to select 4 components from the remaining 37 non-defective components in the sample. As for total, 5 components out of 40 are to be selected, thus, we have for the hypergeometric distribution:
#
# k = 3; x = 1; N = 40; n = 5
#
# $P(X = 1)$ = ($^kC_x * ^{N-k}C_{n-x}$)/$^{40}C_5$ = $^3C_1 * 37^C_4$ / 658008 = 0.3011
#
# ### Example 5.10:
# For the given case, we have:
#
# For 3 defective found in the sample for total of 12 defectives, then we have to select the other 7 for the sample as non-defective from a total of 88 non-defectives. Overall the probability will be given for selecting 10 random components from a total of 100. Using hypergeometric distribution, we have:
#
# k = 12; x = 3; n = 10; N = 100
#
# $b(x: N,n,k)$ = ($^kC_x * ^{N-k}C_{n-x}$) / ($^{100}C_{10}$) = ($^{12}C_3 * ^{88}C_{7}$) / ($^{100}C_{10}$) = 0.0807
#
# ### Example 5.11:
# For the case of Example 5.9, we have:
#
# N = 40; n = 5; k = 3; x = 1
#
# We have:
#
# Mean = $\mu$ = nk/N = (5)(3)/(40) = 0.375
#
# Variance = $\sigma^2$ = (N - n)/(N - 1) $*$ nk/N $*$ (1 - k/N) = (40 - 3)/(40 - 1) $*$ (5)(3)/(40) $*$ (1 - (3)/(40)) = 0.329
#
# ### Example 5.12:
# For the given case, we have to get the event that 3 of the tires are blemished out of total 1000, then 7 tires would be un-blemished from a total of 4000 remaining. For the overall, 10 tires are to be purchased from a total of 5000 whether they be blemish or not. Thus, for the hypergeometric distribution, we have:
#
# x = 3; k = 1000; N = 5000; n = 10
#
# Now, we have:
#
# $P(X = 3)$ = ($^kC_x * ^{N-k}C{n-x}$) / $^{5000}C_{10}$ = ($^{1000}C_{3} * ^{5000-1000}C_{10-3}$) / ($^{5000}C_{10}$) = 0.2015
#
# ### Example 5.13:
# For the given case, we have:
#
# A: Random variable representing people with blood type A
#
# B: Random variable representing people with blood type B
#
# O: Random variable representing people with blood type O
#
# Now, we have to select a total of 5 people from the group of 10, where 2 people with A have to be selected from a total of 4, 2 people with B have to be selected from a total of 3 and 1 person with O has to be selected from a total of 3, thus, for the multivariate hypergeometric distribution, we have:
#
# a = 2; b = 2; o = 1; $k_a$ = 4; $k_b$ = 3; $k_o$ = 3; N = 10; n = 5
#
# $f(a,b,o: k_a, k_b, k_o, N, n)$ = ($^{k_a}C_a * ^{k_b}C_b * ^{k_o}C_o$) / ($^{10}C_5$) = ($^4C_2 * ^3C_2 * ^3C_1$) / $^{10}C_5$ = 0.2143
#
# ## Exercises:
#
# ### Exercise 5.29:
# For the given case, we have to select a total of 6 bulbs from 9 bulbs in the box, where we have to select 2 daffodil bulbs from a total of 4 and 4 tulip bulbs from a total of 5, thus, for the hyper geometric distribution, we have:
#
# k = 4; x = 2; n = 6; N = 9
#
# $P(X = 2)$ = ($^kC_x * ^{N-k}C_{n-x}$) / $^9C_6$ = ($^4C_2 * ^{9-4}C_{6-2}$) / $^9C_6$ = 0.3571
#
# ### Exercise 5.30:
# For the given case, the custom officer has to select 3 tablets from a total of 15 tablets (6 narcotic and 9 vitamin), where even if one of the tablets turns out to be from total of 6 narcotic tablets, then the traveler will be arrested, thus, we have for the hyper geometric distribution, we have:
#
# k = 6; n = 3; N = 15
#
# $P(X \geq 1)$ = 1 - $P(X = 0)$ = 1 - $b(0: 15,3,6)$ = 1 - ($^6C_0 * ^{15-6}C_{3-0}$)/($^15C_3$) = 1 - 0.1846 = 0.8154
#
# ### Exercise 5.31:
# Let X be the number of doctors on the committe then we have to select a total of 3 members from 6 (4 doctors and 2 nurses). Thus, we have for our formula:
#
# k = 4; n = 3; N = 6
#
# $P(X = x)$ = $b(x: N,n,k)$ = $^4C_x * ^{6-4}C_{3-x}$ / $^6C_3$ --(i)
#
# Now, for given case, we have:
#
# $P(2 \leq X \leq 3)$ = $P(X = 2)$ + $P(X = 3)$ = ($^4C_2 * ^{6-4}C_{3-2}$ / $^6C_3$) + ($^4C_3 * ^{6-4}C_{3-3}$ / $^6C_3$) = 0.6 + 0.2 = 0.8
#
# ### Exercise 5.32:
# Let X be random variable representing the number of missiles fired, then we have to select x non-defective from a total of 7 and the remaining 4-x defective from a total of 3 with overall selection of 4 missiles from a lot of 10, we have using hypergeometric distribution:
#
# k = 7; n = 4; N = 10
#
# $P(X = x)$ = $b(x: N,n,k)$ = $^kC_x * ^{N-k}C_{n-x}$ / $^{10}C_4$ ---(i)
#
# __(a)__ For this case, we have:
#
# $P(X = 4)$ = $^7C_4 * ^{10-7}C_{4-4}$ / $^{10}C_4$ = 0.1667
#
# __(b)__ Let Y be the event that the missiles don't fire, then we have:
#
# k = 3; n = 4; N = 10
#
# $P(Y \leq 2)$ = $\Sigma_{y=0}^{2} b(x: N,n,k)$ = $b(0: 10,4,3)$ + $b(1: 10,4,3)$ + $b(2: 10,4,3)$ = ($^3C_0 * ^{10-3}C_{4-0}$ / ${10}C_4$) + ($^3C_1 * ^{10-3}C_{4-1}$ / ${10}C_4$) + ($^3C_2 * ^{10-3}C_{4-2}$ / ${10}C_4$) = 0.1667 + 0.5 + 0.3 = 0.9667
#
# ### Exercise 5.33:
# For the given set of cards, we have to deal with 7 cards out of a total of 52 cards in the deck i.e:
#
# n = 7; N = 52
#
# __(a)__ For 2 of them to exactly be face cards, we have to select 2 face cards from a total of 12 face cards in the deck i.e. we have:
#
# x = 2; k = 12;
#
# Using hypergeometric distribution, we have:
#
# $P(X = 2)$ = $b(2: 52,7,12)$ = $^{12}C_2 * ^{52-12}C_{7-2}$ / $^{52}C_7$ = 0.3246
#
# __(b)__ For atleast one of them to be queen, we have to select 1 or more queens from a total of 4 queens in the deck i.e. we have:
#
# x $\geq$ 1; k = 4
#
# Using hyper geometric distribution, we have:
#
# $P(X \geq 1)$ = 1 - $P(X = 0)$ = 1 - $b(0: 52,7,12)$ = 1 - ($^{12}C_0 * ^{52-12}C_{7-0}$ / $^{52}C_7$) = 1 - 0.1393
#
# ### Exercise 5.34:
# The waitress has to check 5 students from a total of 9 such that 4 of them are minors. For the given case, the waitress will refuse exaclty two minors if and only if we have:
#
# x = 2; k = 4; n = 5; N = 9
#
# Using nyper geometric distribution, we have:
#
# $P(X = 2)$ = $b(2: 9,5,4)$ = $^{4}C_2 * ^{9-4}C_{5-2}$ / $9C_5$ = 0.4762
#
# ### Example 5.35:
# For the given case, we have:
#
# N = 50; k = 50 $*$ 20% = 10; n = 5; x $\leq$ 2
#
# Using hyper geometric distribution, we have:
#
# $P(X \leq 2)$ = $\Sigma_{x=0}^{2} b(x: N,n,k)$ = $b(0: 50,5,10)$ + $b(1: 50,5,10)$ + $b(2: 50,5,10)$ = ($^{10}C_0 * ^{50-10}C_{5-0}$ / $^{50}C_5$) + ($^{10}C_1 * ^{50-10}C_{5-1}$ / $^{50}C_5$) + ($^{10}C_2 * ^{50-10}C_{5-2}$ / $^{50}C_5$) = 0.3106 + 0.4313 + 0.2098 = 0.9517
#
# ### Exercise 5.36:
# For the given case, 3 boxes are selected from a total of 25, i.e. we have:
#
# N = 25; n = 3
#
# __(a)__ For a box to contain 3 defectives such that it is shipped, means that even though the box contained defectives the checked components were not defective i.e. x = 0 while k = 3. Using hyper geometric distribution, we have:
#
# $P(X = 0)$ = $b(x: N,n,k)$ = $b(0: 25,3,3)$ = $^3C_0 * ^{25-3}C_{3-0}$ / $^{25}C_3$ = 0.6695
#
# __(b)__ For a box to contain 1 defective such that it is send back for scanning, means that the defective in the box was found regardless i.e. x = 1 and k = 1. Using hyper geometric distribution, we have:
#
# $P(X = 1)$ = $b(x: N,n,k)$ = $b(1: 25,3,1)$ = $^1C_1 * ^{25-1}C_{3-1}$ / $^{25}C_3$ = 0.12
#
# ### Exercise 5.37:
# From the case in Exercise 5.36, now with the given conditon, the events of selecting boxes has become independent of each other, thus, it has now become a case of binomail distribution, we have:
#
# n = 3; p = k/N
#
# __(a)__ For the first case, we have:
#
# p = 3/25 = 0.12; q = 1 - p = 1 - 0.12 = 0.88; x = 0
#
# $P(X = 0)$ = $b(0: 3,0.12)$ = $^3C_0$ $*$ (0.12)$^0$ $*$ (0.88)$^{3-0}$ = 0.6815
#
# __(b)__ For the second case, we have:
#
# p = 1/25 = 0.04; q = 1 - p = 1 - 0.04 = 0.96; x = 1
#
# $P(X = 1)$ = $b(1: 3,0.04)$ = $^3C_1$ $*$ (0.04)$^1$ $*$ (0.96)$^{3-1}$ = 0.1106
#
# ### Exercise 5.38:
# We have for the following case: (Since 10 out of total 150 are to be selected where 30 are women)
#
# N = 150; n = 10; k = 30
#
# For binomial approximation, we have:
#
# p = k/N = 30/150 = 0.2; q = 1 - p = 1 - 0.2 = 0.8
#
# Now, we have for atleast 3 women to be selected:
#
# $P(X \geq 3)$ = 1 - $P(X \leq 2)$ = 1 - $\Sigma_{x=0}^{2} b(x: n,p)$ = 1 - ($b(0: 10,0.2)$ + $b(1: 10,0.2)$ + $b(2: 10,0.2)$) =
# 1 - (0.1074 + 0.2684 + 0.3019) = 1 - 0.6777 = 0.3223
#
# ### Exercise 5.39:
# We have for the following case: (Since 10 out of total 1200 residences are being selected where half i.e 600 are in favour of being annexed)
#
# N = 1200; n = 10; k = 600
#
# For binomial approximation, we have:
#
# p = k/N = 600/1200 = 1/2 = 0.5; q = 1 - p = 1 - 0.5 = 0.5
#
# Now, we have for atleast 3 ni favour of annexure:
#
# $P(X \geq 3)$ = 1 - $P(X \leq 2)$ = 1 - $\Sigma_{x=0}^{2} b(x: n,p)$ = 1 - ($b(0: 10,0.5)$ + $b(1: 10,0.5)$ + $b(2: 10,0.5)$) = 1 - (0.00098 + 0.00976 + 0.0439) = 1 - 0.05464 = 0.9453
#
# ### Exercise 5.40:
# We have for the following case: (Since 15 votes are to be selected from a total of 10000, where 4000 are against the new sales tax and 6000 are in favour)
#
# N = 10000; n = 10; k = 6000
#
# For the binomial approximation:
#
# p = k/N = 6000/10000 = 0.6; q = 1 - p = 1 - 0.6 = 0.4
#
# Now, for at most 7 to votes in favour, we have:
#
# $P(X \leq 7)$ = 1 - $P(X \geq 8)$ = 1 - $\Sigma_{x=8}^{10} b(x: n,p)$ = 1 - ($b(8: 10,0.6)$ + $b(9: 10,0.6)$ + $b(10: 10,0.6)$) = 1 - (0.1209 + 0.0403 + 0.0060) = 1 - 0.1672 = 0.8328
#
# ### Exercise 5.41:
# We have for the following case: (Since 18 seniors are to be selected from a total of 17000 where 70% disapprove to daily pot smoking)
#
# N = 17000; n = 18; k = 17000 $*$ 70% = 11900
#
# For the binomial approximation:
#
# p = k/N = 11900/17000 = 0.7
#
# Now, for more than 9 but fewer than 14 students to disaaprove daily pot we have:
#
# $P(9 < X < 14)$ = $\Sigma_{x=10}^{13} b(x: n,p)$ = $b(10: 18,0.7)$ + $b(11: 18,0.7)$ + $b(12: 18,0.7)$ + $b(13: 18,0.7)$ = 0.0811 + 0.1376 + 0.1873 + 0.2017 = 0.6077
#
# ### Exercise 5.42:
# To deal a bridge, we need to select 13 cards from a total of 52 cards. For the given case, we must select 5 spades from a total of 13, 2 hearts from a total of 13, 3 diamonds from a total of 13 and 3 clubs from a total of 13, hence, we have for the multi-hyper geometric distribution:
#
# $x_1$ = 5; $x_2$ = 2; $x_3$ = 3; $x_4$ = 3; $k_1$ = 13; $k_2$ = 13; $k_3$ = 13; $k_4$ = 13; n = 13; N = 52
#
# We have:
#
# $f(x_1,x_2,x_3,x_4: N,n,k_1,k_2,k_3,k_4)$ = ($^{13}C_5 * ^{13}C_2 * ^{13}C_3 * ^{13}C_3$) / $^{52}C_{13}$ = 0.0129
#
# ### Exercise 5.43:
# For the given case, we have: (values $k_1, k_2, k_3, k_4$ represent Canadians, Japanese, Italian and German respectively)
#
# $k_1$ = 2; $k_2$ = 3; $k_3$ = 5; $k_4$ = 2; n = 4; N = 2 + 3 + 5 + 2 = 12
#
# __(a)__ For all nationalities to be represented their must be one student present from each country i.e. we have:
#
# $x_1$ = 1; $x_2$ = 1; $x_3$ = 1; $x_4$ = 1
#
# Now, we have:
#
# $f(x_1, x_2, x_3, x_4: N,n,k_1,k_2,k_3,k_4)$ = ($^2C_1 * ^3C_1 * ^5C_1 * ^2C_1$) / $^{12}C_4$ = 0.1212
#
# __(b)__ For all nationalities except Italian to be present, we have to have one of the following cases:
#
# * 2 Canadians 1 Japanese 1 German
# * 1 Canadian 2 Japanese 1 German
# * 1 Canadian 1 Japanese 2 German
#
# Hence, since its a matter of choice, we will apply addition rule to the multivariate hypergeometric series, we have:
#
# $f(2,1,0,1: 12,4,2,3,5,2)$ + $f(1,2,0,1: 12,4,2,3,5,2)$ + $f(1,1,0,2: 12,4,2,3,5,2)$ = (($^2C_2 * ^3C_1 * ^5C_0 * ^2C_1$) / $^{12}C_4$) + (($^2C_1 * ^3C_2 * ^5C_0 * ^2C_1$) / $^{12}C_4$) + (($^2C_1 * ^3C_1 * ^5C_0 * ^2C_2$) / $^{12}C_4$) = 0.01212 + 0.02424 + 0.01212 = 0.04848
#
# ### Exercise 5.44:
# For the given case, we have:
#
# B: Random variable representing number of blue balls
#
# R: Random variable representing number of red balls
#
# G: Random variable representing number of green balls
#
# Now, we have:
#
# $k_b$ = 2; $k_r$ = 4; $k_g$ = 3; n = 5; N = 2 + 4 + 3 = 9
#
# Now, for the given case, we have to have both blue balls and atleast 1 red ball i.e:
#
# b = 2; r $\geq$ 1; g $\leq$ 2 (green balls are less than equal to 2 because out of the five balls given, 2 will be blue which leaves us with 3 balls. The condition specifies that at least 1 ball would be red this means that for the case of 1 red we will have 2 greens, for 2 reds we will have 1 green and for 3 reds we will have 0 greens)
#
# $P(B = 2; 1 \geq R \leq 3; G \leq 2)$ = $\Sigma_{r=1}^{3} f(b,r,g: N,n,k_b,k_r,k_g)$ = $f(2,1,2: 9,5,2,4,3)$ + $f(2,2,1: 9,5,2,4,3)$ + $f(2,3,0: 9,5,2,4,3)$ = (($^2C_2 * ^4C_1 * ^3C_2$) / $^9C_5$) + (($^2C_2 * ^4C_2 * ^3C_1$) / $^9C_5$) + (($^2C_2 * ^4C_3 * ^3C_0$) / $^9C_5$) = 0.0952 + 0.1428 + 0.0317 = 0.2697
#
# ### Exercise 5.45:
# We are selecting 15 animals for our sample from a total of 25 animals, where 10 are tagged. Now, for the sample to contain 5 tagged animals, we have:
#
# x = 5; k = 10; n = 15; N = 25
#
# Applying hypergeometric distribution, we have:
#
# $P(X = 5)$ = $b(5: 25,15,10)$ = $^{10}C_5 * ^{25-10}C_{15-5}$ / $^{25}C_{15}$ = 0.2315
#
# ### Exercise 5.46:
# We have to take 5 compressors for our sample from a total of 15 compressors in a given batch, where 2 are faulty, thus, we have:
#
# k = 2; n = 5; N = 15
#
# __(a)__ For the given case of having 1 faulty compressor in our sample, we have:
#
# $P(X = 1)$ = $b(1: 15,5,2)$ = $^2C_1 * ^{15-2}C_{5-1}$ / $^{15}C_5$ = 0.4762
#
# __(b)__ For the given case of discovering both the faulty compressors in our sample, we have:
#
# $P(X = 2)$ = $b(2: 15,5,2)$ = $^2C_2 * ^{15-2}C_{5-2}$ / $^{15}C_5$ = 0.0952
#
# ### Exercise 5.47:
# For the given case, we have a total of 20 firms from which 3 are in violation i.e. we have:
#
# N = 20; k = 3
#
# __(a)__ For no violations to be caught for a sample of 5 firms, we have:
#
# n = 5; x = 0
#
# Using hyper geometric distribution, we have:
#
# $P(X = 0)$ = $b(0: 20,5,3)$ = $^3C_0 * ^{20-3}C_{5-0}$ / $^{20}C_5$ = 0.3991
#
# __(b)__ For 2 violations to be caught for the above scenario, we have:
#
# $P(X = 2)$ = $b(2: 20,5,3)$ = $^3C_2 * ^{20-3}C_{5-2}$ / $^{20}C_5$ = 0.1316
#
# ### Exercise 5.48:
# For given case, we have to select 30 cans for our sample from a total of 10,000 cans, where 300 are underfilled i.e. we have:
#
# N = 10000, n = 30; k = 300
#
# For atleast one underfilled can, we have by the hyper geometric distribution:
#
# $P(X \geq 1)$ = 1 - $P(X = 0)$ = 1 - $b(0: 10000,30,300)$ = 1 - ($^{300}C_0 * ^{10000-300}C_{30-0}$ / $^{10000}C_{30}$) = 1 - 0.4 = 0.6
